# %%
import pandas
import pandas as pd
Ba_Res=pd.read_excel(r"C:\Users\hp\Shamshad\Bangalore_Restaurents_Food_Types.xlsx")
Ba_Res
# Out:
#       S.No.   Restaurent_Name                                      Item_Name  \
# 0       1.0  Gufha Restaurant                                Chicken Biryani
# 1       NaN  Gufha Restaurant                                Chicken Lolipop
# 2       NaN  Gufha Restaurant                                  Chicken Tikka
# 3       NaN  Gufha Restaurant                            Chicken Malai Tikka
# 4       NaN  Gufha Restaurant                                 Charliee Kebab
# ...     ...               ...                                            ...
# 1231    NaN    Lotus Pavilion         Grilled Salmon with Lemon Butter Sauce
# 1232    NaN    Lotus Pavilion               Chicken Stroganoff (Continental)
# 1233    NaN    Lotus Pavilion  Mixed Non‑Veg Platter (Chicken, Fish, Prawns)
# 1234    NaN    Lotus Pavilion                           Lamb Chops (Grilled)
# 1235    NaN    Lotus Pavilion                 Seafood Curry (Chef’s Special)
#
#       Prices Prices.1  Rating  \
# ...
